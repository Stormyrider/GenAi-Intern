# %% [markdown]
# <a href="https://colab.research.google.com/github/Stormyrider/GenAi-Intern/blob/main/Converters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("BMI Calculator")

choice = input("Choose an option (1, 2, or 3): ").strip()

if choice == "1":
    celsius = float(input("Enter temperature in Celsius: "))
    fahrenheit = (celsius * 9/5) + 32
    print(f"{celsius}°C = {fahrenheit:.2f}°F")

elif choice == "2":
    km = float(input("Enter distance in Kilometers: "))
    miles = km * 0.621371
    print(f"{km} km = {miles:.2f} miles")

elif choice == "3":
    weight = float(input("Enter weight in kilograms: "))
    height = float(input("Enter height in meters: "))
    bmi = weight / (height ** 2)
    print(f"Your BMI is {bmi:.2f}")

else:
    print("Invalid choice.")
# Out:
# BMI Calculator
# Choose an option (1, 2, or 3): 2
# Enter distance in Kilometers: 50
# 50.0 km = 31.07 miles
