# %% [markdown]
# <a href="https://colab.research.google.com/github/Stormyrider/GenAi-Intern/blob/main/bank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json


class BankAccount:

    def __init__(self, name, balance=0):
        self.name = name
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print("Amount Deposited")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print("Amount Withdrawn")
        else:
            print("Insufficient Balance")

    def __str__(self):
        return f"Name: {self.name}, Balance: {self.balance}"


account = BankAccount("Ahmed", 1000)

print(account)

account.deposit(500)
account.withdraw(200)

print(account)


data = {
    "name": account.name,
    "balance": account.balance
}

file = open("account.json", "w")
json.dump(data, file, indent=4)
file.close()


file = open("account.json", "r")
record = json.load(file)
file.close()

print("\nData Loaded From JSON")
print(record)
# Out:
# Name: Ahmed, Balance: 1000
# Amount Deposited
# Amount Withdrawn
# Name: Ahmed, Balance: 1300
#
# Data Loaded From JSON
# {'name': 'Ahmed', 'balance': 1300}
