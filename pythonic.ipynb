# %% [markdown]
# <a href="https://colab.research.google.com/github/Stormyrider/GenAi-Intern/blob/main/pythonic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# List Comprehension
numbers = [1, 2, 3, 4, 5]
squares = [x * x for x in numbers]
print("Squares:", squares)


# Dictionary Comprehension
students = ["Ali", "Ahmed", "Sara"]
marks = {name: 50 for name in students}
print("Marks:", marks)


# Set Comprehension
numbers = [1, 2, 2, 3, 3, 4, 5]
unique = {x for x in numbers}
print("Unique Numbers:", unique)


# Generator Expression
numbers = (x * x for x in range(5))
print("Generator Values:")
for value in numbers:
    print(value)


# Lambda Function
add = lambda a, b: a + b
print("Addition:", add(10, 20))


# Map Function
numbers = [1, 2, 3, 4, 5]
double = list(map(lambda x: x * 2, numbers))
print("Doubled:", double)


# Filter Function
numbers = [1, 2, 3, 4, 5, 6]
even = list(filter(lambda x: x % 2 == 0, numbers))
print("Even Numbers:", even)


# Sorted with Key
names = ["Ahmed", "Ali", "Muhammad", "Sara"]
sorted_names = sorted(names, key=len)
print("Sorted by Length:", sorted_names)


# Enumerate
fruits = ["Apple", "Banana", "Mango"]

print("Enumerate:")
for index, fruit in enumerate(fruits):
    print(index, fruit)


# Zip
names = ["Ali", "Ahmed", "Sara"]
ages = [20, 21, 22]

print("Zip:")
for name, age in zip(names, ages):
    print(name, age)


# Try Except Else Finally
try:
    number = int(input("Enter a number: "))
    result = 100 / number
except ValueError:
    print("Please enter a valid number.")
except ZeroDivisionError:
    print("Number cannot be zero.")
else:
    print("Result:", result)
finally:
    print("Program Finished.")


# Custom Exception
class NegativeNumberError(Exception):
    pass


try:
    value = int(input("Enter a positive number: "))

    if value < 0:
        raise NegativeNumberError("Negative numbers are not allowed.")

    print("You entered:", value)

except NegativeNumberError as e:
    print(e)
# Out:
# Squares: [1, 4, 9, 16, 25]
# Marks: {'Ali': 50, 'Ahmed': 50, 'Sara': 50}
# Unique Numbers: {1, 2, 3, 4, 5}
# Generator Values:
# 0
# 1
# 4
# 9
# 16
# Addition: 30
# Doubled: [2, 4, 6, 8, 10]
# Even Numbers: [2, 4, 6]
# Sorted by Length: ['Ali', 'Sara', 'Ahmed', 'Muhammad']
# Enumerate:
# 0 Apple
# 1 Banana
# 2 Mango
# Zip:
# Ali 20
# Ahmed 21
# Sara 22
# Enter a number: 1
# Result: 100.0
# Program Finished.
# Enter a positive number: 16
# You entered: 16
